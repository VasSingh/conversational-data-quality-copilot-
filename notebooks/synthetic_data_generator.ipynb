# %% [markdown]
# # Synthetic Data Generator
#
# This notebook generates the CSV datasets used by the Conversational Data Quality Copilot.

# %%
from app.synthetic_data import ensure_data
ensure_data('data')
print('Data generated in ./data')
